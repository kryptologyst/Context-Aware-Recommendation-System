# %% [markdown]
# # Context-Aware Recommendation System
#
# This notebook demonstrates how to use the context-aware recommendation system with various models and evaluation metrics.

# %%
import pandas as pd
import numpy as np
from omegaconf import OmegaConf

from src.data.dataset import DatasetGenerator
from src.data.preprocessing import DataSplitter
from src.models.baselines import PopularityRecommender, UserKNNRecommender
from src.models.advanced import ALSRecommender, ContentBasedRecommender
from src.evaluation.metrics import ModelEvaluator
from src.utils.helpers import validate_data_quality, print_data_quality_report
